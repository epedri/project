# %%
#import numpy as np
#import pandas as pd
import geopandas as gpd

#import matplotlib.pyplot as plt
#import seaborn as sns
#import plotly.express as px
#import folium

from utils import *

# %%
data = gpd.read_file("data/data.shp")
data.columns = ['playground_quality', 
                'picnic_quality', 
                'parks_quality', 
                'sport_quality', 
                'sport_entities_quality',
                'hotels_quality', 
                'recycling_quality', 
                'restrooms_quality', 
                'funiculars_quality', 
                'electrocar_quality',
                'tracks_quality', 
                'bicicle_quality', 
                'roads_quality', 
                'greens_quality',
                'dog_quality',
                'field_quality', 
                'metro_quality', 
                'train_quality', 
                'theatres_quality', 
                'museums_quality',
                'papelarias_quality', 
                'monuments_quality', 
                'malls_quality', 
                'mercados_quality', 
                'feiras_quality',
                'private_quality', 
                'public_quality', 
                'bombeiros', 
                'private_ho', 
                'public_hos',
                'pharmacies', 
                'health_cen', 
                'police_qua', 
                'public_kin', 
                'university',
                'profession', 
                'private_ki', 
                'special_sc', 
                'Shape_Leng', 
                'Shape_Area',
                'geometry']

# %%
# Out:
# 35

# %%
data.explore(column='metro_quality', tiles='CartoDB dark_matter', cmap="RdYlGn")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
tring = user_importance(data, [("metro_quality", 1),
                       ("train_quality", 1)])
type(tring.explore(column='result', tiles='CartoDB dark_matter', cmap="RdYlGn", vmin=0, vmax=5))
# Out:
# folium.folium.Map
